# %%
import anndata
import pandas as pd
from pathlib import Path

llava_annotations=pd.read_csv(snakemake.input.cellwhisperer_labels, index_col=0)["annotation"]

# %%
# snakemake.input.model = '/msc/home/mschae83/text-generation-webui/models/mixtral-8x7b-instruct-v0.1.Q5_K_M.gguf'

# %%
from llama_cpp import (
    Llama,
    LlamaGrammar,
)

# load the model
llm = Llama(
    model_path=snakemake.input.model,
    n_ctx=32000,  # The max sequence length to use - note that longer sequence lengths require much more resources
    n_threads=5,  # The number of CPU threads to use
    n_threads_batch=25,
    n_gpu_layers=86,  # High enough number to load the full model
)

# %%
results = {}
for leiden, annotation in llava_annotations.items():
    if not isinstance(annotation, str):
        response = "No label"
    else:
        output = llm(
            f"[INST] {snakemake.params.request}\n{annotation} [/INST]",
            max_tokens=1024,  # for training, we only use a max of 128. observe whether this matches..
            stop=["</s>"],  # stop token for Mixtral
            logit_bias={
                llm.tokenizer().encode("\n")[-1]: float("-inf"),
                llm.tokenizer().encode('"')[-1]: float("-inf")
            },  # Prevent newlines and quotes
            echo=False,  # don't echo the prompt as part of the response
            seed=42,
            temperature=0.2,
            top_p=0.9,
            top_k=50,
        )
        response = output["choices"][0]["text"].strip()
    print(response)
    results[leiden] = response

# %%
series = pd.Series(results)
series.index.name = "leiden_cluster_id"
series.name = "GPT4_curated_labels"
series.to_csv(snakemake.output.curated_labels)

# %%
series
