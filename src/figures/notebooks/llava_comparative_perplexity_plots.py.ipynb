# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use(snakemake.input.mpl_style)

# %%
snakemake.params.comparison_sequence
# Out:
# [{'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'geneformer',
#   'prompt_variation': 'without50topgenes'},
#  {'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'geneformer',
#   'prompt_variation': 'with50topgenes'},
#  {'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'geneformer',
#   'prompt_variation': 'without50topgenesresponsepermuted'},
#  {'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'cellwhisperer_clip_v1',
#   'prompt_variation': 'without50topgenes'},
#  {'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'cellwhisperer_clip_v1',
#   'prompt_variation': 'with50topgenes'},
#  {'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'cellwhisperer_clip_v1',
#   'prompt_variation': 'without50topgenesresponsepermuted'}]

# %%
keys = snakemake.params.comparison_sequence[0]

common_fields = {
    key: snakemake.params.comparison_sequence[0][key]
    for key in snakemake.params.comparison_sequence[0]
    if len(set([v[key] for v in snakemake.params.comparison_sequence])) == 1
}
common_fields
# Out:
# {'base_model': 'Mistral-7B-Instruct-v0.2'}

# %%
dfs = []
for params, fn in zip(
    snakemake.params.comparison_sequence, snakemake.input.perplexities
):
    dfs.append(pd.read_csv(fn, index_col=0))
    dfs[-1]["configuration"] = "__".join(
        [v for k, v in params.items() if k not in common_fields.keys()]
    )
    for key, value in params.items():
        dfs[-1][key] = value

df = pd.concat(dfs)
df
# Out:
# /tmp/ipykernel_2667441/4075621365.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(fn, index_col=0))
# /tmp/ipykernel_2667441/4075621365.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(fn, index_col=0))
# /tmp/ipykernel_2667441/4075621365.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(fn, index_col=0))
# /tmp/ipykernel_2667441/4075621365.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(fn, index_col=0))
# /tmp/ipykernel_2667441/4075621365.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(fn, index_col=0))
# /tmp/ipykernel_2667441/4075621365.py:5: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfs.append(pd.read_csv(fn, index_col=0))
#        eval_loss  eval_model_preparation_time  eval_perplexity  \
# 0       1.747607                       0.0083         5.913177
# 1       1.747607                       0.0083         5.913177
# 2       1.747607                       0.0083         5.913177
# 3       1.747607                       0.0083         5.913177
# 4       1.747607                       0.0083         5.913177
# ...          ...                          ...              ...
# 15153   1.824078                       0.0089         6.374437
# 15154   1.824078                       0.0089         6.374437
# 15155   1.824078                       0.0089         6.374437
# 15156   1.824078                       0.0089         6.374437
# 15157   1.824078                       0.0089         6.374437
#
#        eval_all_perplexities  eval_runtime  eval_samples_per_second  \
# 0                     6.1875      714.9566                   21.201
# 1                     5.9375      714.9566                   21.201
# 2                     8.2500      714.9566                   21.201
# 3                     9.8125      714.9566                   21.201
# 4                     7.7500      714.9566                   21.201
# ...                      ...           ...                      ...
# 15153                 7.7500      740.4888                   20.470
# 15154                 5.6250      740.4888                   20.470
# 15155                 8.5000      740.4888                   20.470
# 15156                 4.6875      740.4888                   20.470
# 15157                 6.5625      740.4888                   20.470
#
#        eval_steps_per_second  \
# 0                      2.651
# 1                      2.651
# 2                      2.651
# 3                      2.651
# 4                      2.651
# ...                      ...
# 15153                  2.559
# 15154                  2.559
# 15155                  2.559
# 15156                  2.559
# 15157                  2.559
#
#                                                 response       type  question  \
# 0      The 50 most strongly expressed genes are TIMP1...    correct       0.0
# 1      The 50 most strongly expressed genes are HSPA1...    correct       1.0
# 2      The 50 most strongly expressed genes are PYY, ...    correct       2.0
# 3      The 50 most strongly expressed genes are INS, ...    correct       3.0
# 4      The 50 most strongly expressed genes are RBP2,...    correct       4.0
# ...                                                  ...        ...       ...
# 15153                                                NaN  incorrect       NaN
# 15154                                                NaN  incorrect       NaN
# 15155                                                NaN  incorrect       NaN
# 15156                                                NaN  incorrect       NaN
# 15157                                                NaN  incorrect       NaN
#
#        replicate  question_id  \
# 0             -1          NaN
# 1             -1          NaN
# 2             -1          NaN
# 3             -1          NaN
# 4             -1          NaN
# ...          ...          ...
# 15153         29      15153.0
# 15154         29      15154.0
# 15155         29      15155.0
# 15156         29      15156.0
# 15157         29      15157.0
#
#                                            configuration  \
# 0                          geneformer__without50topgenes
# 1                          geneformer__without50topgenes
# 2                          geneformer__without50topgenes
# 3                          geneformer__without50topgenes
# 4                          geneformer__without50topgenes
# ...                                                  ...
# 15153  cellwhisperer_clip_v1__without50topgenesrespon...
# 15154  cellwhisperer_clip_v1__without50topgenesrespon...
# 15155  cellwhisperer_clip_v1__without50topgenesrespon...
# 15156  cellwhisperer_clip_v1__without50topgenesrespon...
# 15157  cellwhisperer_clip_v1__without50topgenesrespon...
#
#                      base_model                  model  \
# 0      Mistral-7B-Instruct-v0.2             geneformer
# 1      Mistral-7B-Instruct-v0.2             geneformer
# 2      Mistral-7B-Instruct-v0.2             geneformer
# 3      Mistral-7B-Instruct-v0.2             geneformer
# 4      Mistral-7B-Instruct-v0.2             geneformer
# ...                         ...                    ...
# 15153  Mistral-7B-Instruct-v0.2  cellwhisperer_clip_v1
# 15154  Mistral-7B-Instruct-v0.2  cellwhisperer_clip_v1
# 15155  Mistral-7B-Instruct-v0.2  cellwhisperer_clip_v1
# 15156  Mistral-7B-Instruct-v0.2  cellwhisperer_clip_v1
# 15157  Mistral-7B-Instruct-v0.2  cellwhisperer_clip_v1
#
#                         prompt_variation
# 0                      without50topgenes
# 1                      without50topgenes
# 2                      without50topgenes
# 3                      without50topgenes
# 4                      without50topgenes
# ...                                  ...
# 15153  without50topgenesresponsepermuted
# 15154  without50topgenesresponsepermuted
# 15155  without50topgenesresponsepermuted
# 15156  without50topgenesresponsepermuted
# 15157  without50topgenesresponsepermuted
#
# [2819388 rows x 16 columns]

# %%
if np.isnan(df["question_id"]).any():
    df["question_id"] = df.index

# %%
import json

with open(snakemake.input.evaluation_dataset) as f:
    evaluation_dataset = json.load(f)
evaluation_dataset

df["response"] = df["question_id"].map(
    lambda i: evaluation_dataset[i]["conversations"][1]["value"].replace(
        snakemake.params.response_prefix, ""
    )
)

# %%
df.iloc[0]
# Out:
# eval_loss                                                               1.747607
# eval_model_preparation_time                                               0.0083
# eval_perplexity                                                         5.913177
# eval_all_perplexities                                                     6.1875
# eval_runtime                                                            714.9566
# eval_samples_per_second                                                   21.201
# eval_steps_per_second                                                      2.651
# response                       The 50 most strongly expressed genes are TIMP1...
# type                                                                     correct
# question                                                                     0.0
# replicate                                                                     -1
# question_id                                                                    0
# configuration                                      geneformer__without50topgenes
# base_model                                              Mistral-7B-Instruct-v0.2
# model                                                                 geneformer
# prompt_variation                                               without50topgenes
# Name: 0, dtype: object

# %% [markdown]
# ## Strategy
#
# 1. Compute the expected (i.e. mean over the 30 mismatched cases) ppl ratio between correct and incorrect embedding
# 2. plot method-grouped violin plots of these ratios
#
# ### For main and TabSap
#
# - violinplots across all responses
#
# ### For TabSap
#
# - Make 20 plots (4x5) for the selected ones
# - For the full 177 cell types:
#   - Just take the ranks (how often was method A first, how often was B first, how often was C first, ...)

# %%
if snakemake.wildcards.plot_metric == "log2_ppl_ratio":
    # Compute the expected perplexity ratio for each model
    def ppl_ratio(group):
        correct = group.loc[group.type == "correct", "eval_all_perplexities"]
        assert len(correct) == 1, "There should be exactly one correct answer"
        incorrect = group.loc[group.type == "incorrect", "eval_all_perplexities"]

        return correct.iloc[0] / incorrect.mean()

    ppl_ratios = (
        df.groupby(
            ["configuration", "question_id"] + list(snakemake.params.comparison_sequence[0].keys())
        )
        .apply(ppl_ratio)
        .reset_index()
    )
    response = df.drop_duplicates(
        subset=["question_id", "configuration", "response"]
    ).set_index(["question_id", "configuration"])["response"]
    ppl_ratios["response"] = ppl_ratios.apply(
        lambda row: response.loc[row["question_id"], row["configuration"]], axis=1
    )
    ppl_ratios[snakemake.wildcards.plot_metric] = np.log2(ppl_ratios[0])

    ppl_df = ppl_ratios.reset_index()
elif snakemake.wildcards.plot_metric == "log2_correct_ppl":
    # just show the (log2) of the (correct) perplexity
    ppl_df = (
        df[df.type == "correct"]
        .groupby(["configuration", "question_id", "response"] + list(snakemake.params.comparison_sequence[0].keys()))["eval_all_perplexities"]
        .mean()
        .apply(np.log2)
        .reset_index()
    )
    ppl_df[snakemake.wildcards.plot_metric] = ppl_df["eval_all_perplexities"]

# %%
# Plot individual performance

fig, ax = plt.subplots(figsize=(5, 5))

x = "configuration"
hue = None

if snakemake.wildcards.plot_type == "llava_cw_vs_geneformer":
    x = "prompt_variation"
    hue = "model"
if snakemake.wildcards.plot_type == "gene_predictability":
    pass
if snakemake.wildcards.plot_type == "text_only_vs_cw":
    pass
if snakemake.wildcards.plot_type == "cw_preprompt_useless":
    pass

sns.boxplot(
    data=ppl_df,
    x=x,
    y=snakemake.wildcards.plot_metric,
    hue=hue,
    ax=ax,
)
ax.set_title(
    f"{snakemake.wildcards.plot_type}, {snakemake.wildcards.dataset}  ({', '.join(common_fields.values())})"
)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
plt.tight_layout()


fig.savefig(snakemake.output.individual_performances)
# Out:
# /tmp/ipykernel_2667441/4266123796.py:28: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")

# %% [markdown]
# A bit disturbing that Mistral-7B__NONE with top 50 genes (blue) is better than any multimodal LLM.
# Reason though: The negatives (wrong embeddings) as (as well as the positives) in the original Mistral lead to much larger ppls.
#
# Thus better would be to normalize across the mean of all negatives?

# %% [markdown]
# ### Relative comparisons

# %%
from itertools import combinations

# Find unique configurations
configurations = ppl_df["configuration"].unique()

# Initialize comparison matrix
comparison_matrix = pd.DataFrame(0, index=configurations, columns=configurations)

# Compare configurations
for question_id, group in ppl_df.groupby("question_id"):
    pairs = combinations(group["configuration"], 2)
    for config1, config2 in pairs:
        value1 = group.loc[
            group["configuration"] == config1, snakemake.wildcards.plot_metric
        ].values[0]
        value2 = group.loc[
            group["configuration"] == config2, snakemake.wildcards.plot_metric
        ].values[0]
        if value1 <= value2:
            comparison_matrix.loc[config1, config2] += 1
            comparison_matrix.loc[config2, config1] -= 1
        if value1 >= value2:
            comparison_matrix.loc[config2, config1] += 1
            comparison_matrix.loc[config1, config2] -= 1

# Normalize the matrix to get percentages
# comparison_matrix = comparison_matrix.div(comparison_matrix.sum(axis=1), axis=0) * 100

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    comparison_matrix,
    annot=True,
    cmap="RdBu",
    center=0,
    cbar_kws={"label": "Relative performance"},
)
plt.title(f"Configuration Performance Comparison {snakemake.wildcards.plot_metric}")
plt.xlabel("Configuration")
plt.ylabel("Configuration")
plt.savefig(snakemake.output.relative_performances)

# %% [markdown]
# ### By cell type (works for tab sap only)
#
#
# - Make 20 plots (4x5) for the selected ones
# - For the full 177 cell types:
#   - Just take the ranks (how often was method A first, how often was B first, how often was C first, ...)

# %%
fig, axes = plt.subplots(4, 5, figsize=(20, 16), sharex=True, sharey=True)
for ax, celltype in zip(axes.ravel(), snakemake.params.plot_celltypes):
    # Plot the ratio of positive to negative perplexities
    sns.boxplot(
        data=ppl_df.loc[ppl_df.response == celltype].reset_index(),
        x="configuration",
        y=snakemake.wildcards.plot_metric,
        ax=ax,
    )
    ax.set_title(celltype)

# For lowest row, set x labels
for ax in axes[-1]:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")

plt.tight_layout()

# plt.savefig(snakemake.output.by_celltype)
# Out:
# /tmp/ipykernel_2667441/3695992018.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
# /tmp/ipykernel_2667441/3695992018.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
# /tmp/ipykernel_2667441/3695992018.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
# /tmp/ipykernel_2667441/3695992018.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
# /tmp/ipykernel_2667441/3695992018.py:14: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")
