# %%
import numpy as np

# %%
data = np.load(snakemake.input.processed_dataset, allow_pickle=True)
data = dict(data)

# %%
data["transcriptome_embeds"] = data["transcriptome_features"]
del data["transcriptome_features"]
data

# %%
np.savez(snakemake.output.model_outputs, **data)
