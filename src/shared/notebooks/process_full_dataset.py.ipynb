# %%
import torch

torch.set_num_threads(snakemake.threads)
import logging
import numpy as np
from cellwhisperer.jointemb.cellwhisperer_lightning import (
    TranscriptomeTextDualEncoderLightning,
)
from cellwhisperer.jointemb.processing import TranscriptomeTextDualEncoderProcessor
from cellwhisperer.config import get_path, model_path_from_name
from cellwhisperer.jointemb.dataset.inference import CellxGenePreparationLoader
import anndata
import scanpy as sc
from PIL import Image

# %%
# configure logging
log_file = snakemake.log.log_file  # Get the log file path from Snakemake
logging.basicConfig(
    filename=log_file,
    filemode="a",  # Append to the existing log file
    level=logging.INFO,  # Set the logging level (e.g., DEBUG, INFO, WARNING, ERROR, CRITICAL)
    format="%(asctime)s - %(name)s - %(levelname)s - %(message)s",  # Define the log message format
)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
pl_model = TranscriptomeTextDualEncoderLightning.load_from_checkpoint(
    snakemake.input.model
)
pl_model.eval().to(device)
pl_model.model.prepare_models(
    pl_model.model.transcriptome_model, pl_model.model.text_model, pl_model.model.image_model,     force_freeze=True
)
pl_model.freeze()

# %%
# Check for spatial/image data compatibility
adata = sc.read_h5ad(snakemake.input.read_count_table)
print(f"Loaded dataset with shape: {adata.shape}")

# Check for spatial coordinates and image data
has_spatial = 'X_spatial' in adata.obsm or 'spatial' in adata.obsm
has_image = '20x_slide' in adata.uns or any('images' in adata.uns.get('spatial', {}).get(k, {}) for k in adata.uns.get('spatial', {}))
# has_patches = 'image_patches' in adata.obsm or 'patches' in adata.obsm


print(f"Has spatial coordinates: {has_spatial}")
print(f"Has image data: {has_image}")
# print(f"Has image patches: {has_patches}")

# %%
adata.obs

# %%
from tqdm.auto import tqdm

# traverse all transcriptomes, log features and embeddings and save them

dl = CellxGenePreparationLoader(
    read_count_table=snakemake.input.read_count_table,
    transcriptome_processor=pl_model.model.transcriptome_model.config.model_type,
    image_processor=pl_model.model.image_model.config.model_type,
    batch_size=32,
)

# %%
# Process transcriptome embeddings
transcriptome_results = []
image_results = [] 
for batch in tqdm(dl, desc="Processing transcriptomes"):
    transcriptome_features, transcriptome_embeds = (
        pl_model.model.get_transcriptome_features(
            **{k: t.to(device) for k, t in batch.items() if k != "patches"},  # drop filtering for "patches"
            normalize_embeds=True,
        )
    )
    transcriptome_results.append(
        {
            k: t.detach().cpu()
            for k, t in zip(
                ["transcriptome_features", "transcriptome_embeds"],
                [transcriptome_features, transcriptome_embeds],
            )
        }
    )
    if "patches" in batch: 
        image_features, image_embeds = (
            pl_model.model.get_image_features(
                **{k: t.to(device) for k, t in batch.items()},
                normalize_embeds=True,
                
            )
        )
        image_results.append(
            {
                k: t.detach().cpu()
                for k, t in zip(
                    ["image_features", "image_embeds"],
                    [image_features, image_embeds],
                )
            }
    )

# %% [raw]
# if has_patches:
#     # Direct patch processing
#     if 'image_patches' in adata.obsm:
#         patches = adata.obsm['image_patches']
#     else:
#         patches = adata.obsm['patches']
#
#     print(f"Found {len(patches)} image patches")
#
#     # Get image processor
#     image_processor = pl_model.model.processor.image_processor
#
#     # Process patches in batches
#     batch_size = 16  # Smaller batch size for images
#     image_features_list = []
#     image_embeds_list = []
#
#     for i in tqdm(range(0, len(patches), batch_size), desc="Processing image patches"):
#         batch_patches = patches[i:i + batch_size]
#
#         # Process the batch
#         processed_batch = image_processor(images=batch_patches, return_tensors="pt")
#
#         # Move to device and get embeddings
#         batch_inputs = {k: v.to(device) for k, v in processed_batch.items()}
#         with torch.no_grad():
#             batch_features, batch_embeds = pl_model.model.get_image_features(**batch_inputs, normalize_embeds=True)
#
#         image_features_list.append(batch_features.detach().cpu())
#         image_embeds_list.append(batch_embeds.detach().cpu())
#
#     image_features = torch.cat(image_features_list, dim=0)
#     image_embeddings = torch.cat(image_embeds_list, dim=0)
#
# else:

# %% [raw]
# # Process image embeddings if available and model supports it
# image_embeddings = None
# image_features = None
#
# if has_image and hasattr(pl_model.model, 'image_model') and pl_model.model.image_model is not None:
#     print("Processing image data...")
#
#     # Whole slide image processing
#     image_data = adata.uns['20x_slide']
#
#     # Convert to PIL Image if needed
#     if isinstance(image_data, np.ndarray):
#         if image_data.dtype != np.uint8:
#             image_data = (image_data * 255).astype(np.uint8)
#         if len(image_data.shape) == 2:  # Grayscale
#             image_data = np.stack([image_data] * 3, axis=-1)
#         elif len(image_data.shape) == 3 and image_data.shape[2] == 1:
#             image_data = np.repeat(image_data, 3, axis=2)
#
#         image = Image.fromarray(image_data)
#     else:
#         image = image_data
#
#     # Process image through the model
#     print(f"Processing whole slide image of size: {image.size}")
#
#     # Get image processor
#     image_processor = pl_model.model.processor.image_processor
#
#     # Process image
#     processed_image = image_processor(images=image, return_tensors="pt")
#
#     # Get image embeddings
#     with torch.no_grad():
#         image_inputs = {k: v.to(device) for k, v in processed_image.items()}
#         image_features, image_embeddings = pl_model.model.get_image_features(**image_inputs, normalize_embeds=True)
#
#         # Move to CPU
#         image_features = image_features.detach().cpu()
#         image_embeddings = image_embeddings.detach().cpu()
#
#     print(f"Generated image embeddings with shape: {image_embeddings.shape}")
#
# else:
#     print("No image model available or no image data found")

# %%
# Aggregate transcriptome results
aggregated_dict = {key: torch.cat([d[key] for d in transcriptome_results]) for key in transcriptome_results[0]}
aggregated_dict["orig_ids"] = dl.dataset.orig_ids

# Add image embeddings if available
if image_results:
    aggregated_dict["image_features"] = torch.cat([d["image_features"] for d in image_results])
    aggregated_dict["image_embeds"] = torch.cat([d["image_embeds"] for d in image_results])
    if 'X_spatial' in adata.obsm:
        aggregated_dict["spatial_coordinates"] = torch.tensor(adata.obsm['X_spatial'])
    elif 'spatial' in adata.obsm:
        aggregated_dict["spatial_coordinates"] = torch.tensor(adata.obsm['spatial'])

print(f"Final output keys: {list(aggregated_dict.keys())}")
for key, value in aggregated_dict.items():
    if hasattr(value, 'shape'):
        print(f"{key}: {value.shape}")
    else:
        print(f"{key}: {type(value)}")

# %%
np.savez(snakemake.output["model_outputs"], **aggregated_dict)
print("Processing completed successfully")
