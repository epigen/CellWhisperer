# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/home/users/moritzs/group_home/miniforge3/lib/python3.12/site-packages', '/home/users/moritzs/.cache/snakemake/snakemake/source-cache/runtime-cache/tmpoa1ebakl/file/home/groups/zinaida/moritzs/cellwhisperer_private/src/figures/rules/../notebooks', '/home/groups/zinaida/moritzs/cellwhisperer_private/src/figures/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95\x85!\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8cl/home/groups/zinaida/moritzs/cellwhisperer_private/results/lung_tissue/spotwhisperer_clip_v1/full_output.npz\x94\x8c^/home/groups/zinaida/moritzs/cellwhisperer_private/resources/lung_tissue/read_count_table.h5ad\x94\x8ce/home/groups/zinaida/moritzs/cellwhisperer_private/results/models/jointemb/spotwhisperer_clip_v1.ckpt\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x11processed_dataset\x94K\x00N\x86\x94\x8c\x14raw_read_count_table\x94K\x01N\x86\x94\x8c\x05model\x94K\x02N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x18\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h\x1e)}\x94\x8c\x05_name\x94h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh\x10h\nh\x12h\x0bh\x14h\x0cub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94\x8c\xb2/home/groups/zinaida/moritzs/cellwhisperer_private/results/plots/spotwhisperer_evaluation/spotwhisperer_clip_v1/datasets/lung_tissue/predictions/cell_type_annotations.by_cell.csv\x94a}\x94(h\x0e}\x94\x8c\x0bpredictions\x94K\x00N\x86\x94sh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh/h,ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(\x88\x89]\x94\x8c\nUNASSIGNED\x94ae}\x94(h\x0e}\x94(\x8c\x19use_prefix_suffix_version\x94K\x00N\x86\x94\x8c\x10average_by_class\x94K\x01N\x86\x94\x8c\x0efilter_classes\x94K\x02N\x86\x94uh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bhB\x88hD\x89hFh>ub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x15spotwhisperer_clip_v1\x94\x8c\x0blung_tissue\x94\x8c\x15cell_type_annotations\x94\x8c\x07by_cell\x94e}\x94(h\x0e}\x94(\x8c\x05model\x94K\x00N\x86\x94\x8c\x07dataset\x94K\x01N\x86\x94\x8c\x0cmetadata_col\x94K\x02N\x86\x94\x8c\x08grouping\x94K\x03N\x86\x94uh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh\x14hU\x8c\x07dataset\x94hV\x8c\x0cmetadata_col\x94hW\x8c\x08grouping\x94hXub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94J0W\x05\x00J\xdb\x17\x05\x00\x8cJ cpus-per-task= 5  gpus= 1  constraint=" GPU_MEM:48GB "    partition= gpu \x94e}\x94(h\x0e}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94\x8c\x06mem_mb\x94K\x03N\x86\x94\x8c\x07mem_mib\x94K\x04N\x86\x94\x8c\x05slurm\x94K\x05N\x86\x94uh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bhxK\x01hzK\x01h|hth~J0W\x05\x00h\x80J\xdb\x17\x05\x00h\x82huub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94\x8cp../logs/zero_shot_spotwhisperer_prediction_spotwhisperer_clip_v1_lung_tissue_cell_type_annotations_by_cell.ipynb\x94a}\x94(h\x0e}\x94\x8c\x08notebook\x94K\x00N\x86\x94sh\x16]\x94(h\x18h\x19eh\x18h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x18sNt\x94bh\x19h\x1ch\x1e\x85\x94R\x94(h\x1e)}\x94h"h\x19sNt\x94bh\x94h\x91ub\x8c\x06config\x94}\x94(\x8c\x16anndata_text_obs_label\x94\x8c\x1bnatural_language_annotation\x94\x8c\x0enum_replicates\x94K\x05\x8c\x14llava_projector_type\x94\x8c\rmlp2x_8t_gelu\x94\x8c\x15precomputing_base_url\x94\x8c8https://medical-epigenomics.org/papers/schaefer2024/data\x94\x8c\x0ccluster_name\x94\x8c\x08sherlock\x94\x8c\x05paths\x94}\x94(\x8c\x10read_count_table\x94\x8c)resources/{dataset}/read_count_table.h5ad\x94\x8c\x0fraw_annotations\x94\x8c#resources/{dataset}/annotations.tsv\x94\x8c\x16structured_annotations\x94\x8c"results/{dataset}/annotations.json\x94\x8c\x15processed_annotations\x94\x8c,results/{dataset}/processed_annotations.json\x94\x8c\x1bprocessed_multi_annotations\x94\x8c2results/{dataset}/processed_multi_annotations.json\x94\x8c\x0bgeneset_gmt\x94\x8c\x1eresults/genesets/{library}.gmt\x94\x8c\x17model_processed_dataset\x94\x8c)results/{dataset}/{model}/full_output.npz\x94\x8c\x0cfull_dataset\x94\x8c results/{dataset}/full_data.h5ad\x94\x8c\x12full_dataset_multi\x94\x8c$results/{dataset}/full_data_{i}.h5ad\x94\x8c\x12enrichr_terms_json\x94\x8c"resources/enrichr_terms/terms.json\x94\x8c\x17ensembl_gene_symbol_map\x94\x8c%resources/ensembl_gene_symbol_map.csv\x94\x8c\x0fjointemb_models\x94\x8c\x17results/models/jointemb\x94\x8c\nwandb_logs\x94\x8c\x15results/wandb_logging\x94\x8c\x18datamodule_prepared_path\x94\x8c/results/{dataset}/lightning-processed/{hash}.pt\x94\x8c\x1fdata_loading_individual_samples\x94\x8c\'scratch/data_loading/{dataset_name}_{i}\x94\x8c\x05cache\x94\x8c\rresults/cache\x94\x8c\x18cancer_gene_essentiality\x94}\x94(\x8c\x0fccle_expression\x94\x8c(CCLE_RNAseq_genes_counts_20180929.gct.gz\x94\x8c\x0fessential_genes\x94\x8cEresources/cancer_gene_essentiality/CRISPRInferredCommonEssentials.csv\x94\x8c\x12nonessential_genes\x94\x8cCresources/cancer_gene_essentiality/AchillesNonessentialControls.csv\x94u\x8c\x04gsva\x94}\x94(\x8c\x06result\x94\x8c\x1eresults/{dataset}/gsva.parquet\x94\x8c\x0bcorrelation\x94\x8c/results/{dataset}/{model}/gsva_correlations.csv\x94\x8c\x1ccw_transcriptome_term_scores\x94\x8c>results/{dataset}/{model}/cw_transcriptome_term_scores.parquet\x94\x8c\x05plots\x94\x8c0results/plots/gsva_correlation/{dataset}/{model}\x94u\x8c\x05llava\x94}\x94(\x8c\x04root\x94\x8c\x1dresults/llava{llava_dataset}/\x94\x8c\x15pretrain_text_dataset\x94\x8c0results/llava{llava_dataset}/pretrain_texts.json\x94\x8c\x15finetune_text_dataset\x94\x8c8results/llava{llava_dataset}/finetune_conversations.json\x94\x8c\x17evaluation_text_dataset\x94\x8cDresults/llava{llava_dataset}/evaluation/{dataset}_conversations.json\x94\x8c\x17combined_processed_data\x94\x8c5results/llava_any/combined_processed_data/{model}.npz\x94\x8c\x14pretrained_model_dir\x94\x8c>results/llava{llava_dataset}/pretrained/{base_model}__{model}/\x94\x8c\x13finetuned_model_dir\x94\x8c=results/llava{llava_dataset}/finetuned/{base_model}__{model}/\x94\x8c\x12evaluation_results\x94\x8cVresults/plots/llava{llava_dataset}/{dataset}/{base_model}__{model}/{prompt_variation}/\x94u\x8c\x08geo_umap\x94\x8c\x1fresults/plots/geo_umap/{model}/\x94\x8c\tablations\x94}\x94(\x8c\x06models\x94\x8c\x19results/models/ablations/\x94\x8c\x05plots\x94\x8c\x18results/plots/ablations/\x94uu\x8c\nplot_style\x94\x8c\x19src/plot_style/main.style\x94\x8c\x08datasets\x94]\x94(\x8c\x06immgen\x94\x8c\rhuman_disease\x94\x8c\x0etabula_sapiens\x94\x8c!tabula_sapiens_100_cells_per_type\x94\x8c\narchs4_geo\x94\x8c\x11development4s_raw\x94\x8c\x16development_merged5000\x94\x8c\x05car_t\x94\x8c\rbowel_disease\x94\x8c\x0egut_cell_atlas\x94\x8c\x08pancreas\x94\x8c\x1chcaorganoids_normal__primary\x94\x8c\x1dhcaorganoids_normal__organoid\x94\x8c\x1chcaorganoids_cancer__primary\x94\x8c\x1dhcaorganoids_cancer__organoid\x94\x8c\rdeepspot_test\x94\x8c\x06hest1k\x94\x8c\x0blung_tissue\x94e\x8c.metadata_cols_per_zero_shot_validation_dataset\x94}\x94(\x8c\x06immgen\x94]\x94\x8c\x08celltype\x94a\x8c\rhuman_disease\x94]\x94(\x8c\x0fDisease_subtype\x94\x8c\x06Tissue\x94e\x8c\x08pancreas\x94]\x94\x8c\x08celltype\x94a\x8c\x04aida\x94]\x94\x8c\x08celltype\x94a\x8c\x0etabula_sapiens\x94]\x94(\x8c\x08celltype\x94\x8c\x0corgan_tissue\x94e\x8c%tabula_sapiens_well_studied_celltypes\x94]\x94\x8c\x08celltype\x94a\x8c!tabula_sapiens_100_cells_per_type\x94]\x94(\x8c\x08celltype\x94\x8c\x0corgan_tissue\x94e\x8c\x0blung_tissue\x94]\x94(\x8c\x15cell_type_annotations\x94\x8c\x1dregion_type_expert_annotation\x94eu\x8c\nllava_eval\x94}\x94(\x8c\x11question_celltype\x94\x8c\x1dWhich cell type is this cell?\x94\x8c\x18response_prefix_celltype\x94\x8c\x0fThis cell is a \x94\x8c\x13pre_prompt_topgenes\x94]\x94(}\x94(\x8c\x04from\x94\x8c\x05human\x94\x8c\x05value\x94\x8ccRespond to my request regarding a sample of cells characterized by its top-expressed genes being {}\x94u}\x94(\x8c\x04from\x94\x8c\x03gpt\x94\x8c\x05value\x94\x8c\x1aSure. What\'s your request?\x94ue\x8c\x11question_topgenes\x94\x8cGWhich are the 50 most strongly expressed genes in this sample of cells?\x94\x8c\x18response_prefix_topgenes\x94\x8c+The 50 most strongly expressed genes are {}\x94u\x8c\x1bretrieval_deduplicated_sets\x94}\x94\x8c\x13model_name_path_map\x94}\x94(\x8c\rcellwhisperer\x94\x8c\x15cellwhisperer_clip_v1\x94\x8c\x18cellwhisperer_geneformer\x94\x8c\x15cellwhisperer_clip_v1\x94\x8c\x11cellwhisperer_uce\x94\x8c\x19cellwhisperer_clip_v2_uce\x94\x8c\x13cellwhisperer_scgpt\x94\x8c\x1bcellwhisperer_clip_v2_scgpt\x94\x8c\rspotwhisperer\x94\x8c\x15spotwhisperer_clip_v1\x94\x8c\ngeneformer\x94\x8c\x1cresources/geneformer-12L-30M\x94\x8c\x05scgpt\x94\x8c\x15resources/scGPT_human\x94\x8c\x03uce\x94\x8c!resources/UCE/33layer_model.torch\x94\x8c\tuce4layer\x94\x8c resources/UCE/4layer_model.torch\x94\x8c\x06biogpt\x94\x8c\x10microsoft/biogpt\x94\x8c\x04bert\x94\x8c\x15dmis-lab/biobert-v1.1\x94\x8c\x0ellava_base_llm\x94\x8c\x18Mistral-7B-Instruct-v0.2\x94\x8c\x07mixtral\x94\x8c0resources/mixtral-8x7b-instruct-v0.1.Q5_K_M.gguf\x94\x8c\x07mistral\x94\x8c"resources/Mistral-7B-Instruct-v0.2\x94\x8c\x07llama33\x94\x8c resources/Llama-3.3-70B-Instruct\x94\x8c\x04uni2\x94\x8c\x0fresources/UNI2/\x94\x8c\x13deepspot_pretrained\x94\x8c\x1dresources/deepspot_pretrained\x94\x8c\x03uni\x94\x8c\rresources/UNI\x94\x8c\thoptimus0\x94\x8c\x12resources/hoptimus\x94u\x8c\tuce_paths\x94}\x94(\x8c\x16protein_embeddings_dir\x94\x8c resources/UCE/protein_embeddings\x94\x8c\x0foffset_pkl_path\x94\x8c!resources/UCE/species_offsets.pkl\x94\x8c\x13spec_chrom_csv_path\x94\x8c\x1fresources/UCE/species_chrom.csv\x94\x8c\x06tokens\x94\x8c\x1eresources/UCE/all_tokens.torch\x94\x8c\x0ftmp_pe_idx_path\x94\x8c\x1fresults/UCE/{name}_pe_idx.torch\x94\x8c\x0ftmp_chroms_path\x94\x8c\x1dresults/UCE/{name}_chroms.pkl\x94\x8c\x0ftmp_starts_path\x94\x8c\x1dresults/UCE/{name}_starts.pkl\x94\x8c\x10tmp_feature_path\x94\x8c\x0bresults/UCE\x94u\x8c\x05scfms\x94]\x94(\x8c\ngeneformer\x94\x8c\x05scgpt\x94\x8c\x03uce\x94e\x8c\x08genesets\x94]\x94(\x8c\x0cAzimuth_2023\x94\x8c\x1aGO_Biological_Process_2023\x94\x8c\x1aGO_Molecular_Function_2023\x94\x8c\rOMIM_Expanded\x94\x8c\x18PanglaoDB_Augmented_2021\x94\x8c\x0eTabula_Sapiens\x94e\x8c top20_lung_liver_blood_celltypes\x94]\x94(\x8c\nmacrophage\x94\x8c\x0berythrocyte\x94\x8c\x08monocyte\x94\x8c\x12type ii pneumocyte\x94\x8c\x12classical monocyte\x94\x8c\nneutrophil\x94\x8c\x1fcd4-positive, alpha-beta t cell\x94\x8c\x07nk cell\x94\x8c\x0cnaive b cell\x94\x8c\nbasal cell\x94\x8c\x1fcd8-positive, alpha-beta t cell\x94\x8c\nhepatocyte\x94\x8c;cd8-positive, alpha-beta cytokine secreting effector t cell\x94\x8c\tclub cell\x94\x8c\x16non-classical monocyte\x94\x8c\x1acapillary endothelial cell\x94\x8c&cd4-positive, alpha-beta memory t cell\x94\x8c\rmemory b cell\x94\x8c\x17respiratory goblet cell\x94\x8c\x08basophil\x94e\x8c\x0ecelltype_terms\x94}\x94(\x8c\x0berythrocyte\x94\x8c\x0berythrocyte\x94\x8c\x07nk cell\x94\x8c\x14Natural killer cells\x94\x8c\x06t cell\x94\x8c\x07T cells\x94\x8c\x06b cell\x94\x8c\x07B cells\x94\x8c\x08platelet\x94\x8c\x0fblood platelets\x94u\x8c\x08llm_apis\x94}\x94(\x8c\x04gpt4\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x0eOPENAI_API_KEY\x94\x8c\x08base_url\x94\x8c\x1ahttps://api.openai.com/v1/\x94\x8c\nmodel_name\x94\x8c\x11gpt-4o-2024-11-20\x94u\x8c\x0cclaudesonnet\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x11ANTHROPIC_API_KEY\x94\x8c\x08base_url\x94N\x8c\nmodel_name\x94\x8c\x1aclaude-3-5-sonnet-20241022\x94u\x8c\x07llama33\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x0eOLLAMA_API_KEY\x94\x8c\x08base_url\x94\x8c+http://s0-n02.hpc.meduniwien.ac.at:8080/v1/\x94\x8c\nmodel_name\x94\x8c\x0cllama3.3:70b\x94u\x8c\tmistral7b\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x0eOLLAMA_API_KEY\x94\x8c\x08base_url\x94\x8c+http://s0-n02.hpc.meduniwien.ac.at:8080/v1/\x94\x8c\nmodel_name\x94\x8c\x1dmistral:7b-instruct-v0.2-fp16\x94uuu\x8c\x04rule\x94\x8c"zero_shot_spotwhisperer_prediction\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cQ/home/groups/zinaida/moritzs/cellwhisperer_private/src/figures/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = True; import os; os.chdir(r'/home/groups/zinaida/moritzs/cellwhisperer_private/src/figures');
######## snakemake preamble end #########

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning, module="pandas.core.algorithms")

# %%
import os
from pathlib import Path
import pandas as pd
import logging
import numpy as np
import torch
import scanpy as sc

from cellwhisperer.config import get_path
from cellwhisperer.utils.inference import score_transcriptomes_vs_texts
from cellwhisperer.utils.model_io import load_cellwhisperer_model

# Configure logging
logging.basicConfig(level=logging.INFO)
# Out:
# /home/users/moritzs/group_home/miniforge3/envs/cellwhisperer/lib/python3.10/site-packages/scanpy/_metadata.py:15: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# /home/users/moritzs/group_home/miniforge3/envs/cellwhisperer/lib/python3.10/site-packages/wandb/analytics/sentry.py:90: SentryHubDeprecationWarning: `sentry_sdk.Hub` is deprecated and will be removed in a future major release. Please consult our 1.x to 2.x migration guide for details on how to migrate `Hub` usage to the new API: https://docs.sentry.io/platforms/python/migration/1.x-to-2.x
#   self.hub = sentry_sdk.Hub(client)

# %%
#### Parameters ####
ckpt_file_path = snakemake.input.model
metadata_col = snakemake.wildcards.metadata_col
dataset_name = snakemake.wildcards.dataset
grouping = snakemake.wildcards.grouping
average_by_class = snakemake.params.average_by_class

print(f"Processing dataset: {dataset_name}")
print(f"Metadata column: {metadata_col}")
print(f"Grouping: {grouping}")
print(f"Average by class: {average_by_class}")
# Out:
# Processing dataset: lung_tissue
# Metadata column: cell_type_annotations
# Grouping: by_cell
# Average by class: False

# %%
#### Load model ####
(
    pl_model_cellwhisperer,
    text_processor_cellwhisperer,
    cellwhisperer_transcriptome_processor,
    cellwhisperer_image_processor
) = load_cellwhisperer_model(model_path=ckpt_file_path, eval=True)
cellwhisperer_model = pl_model_cellwhisperer.model

print("Model loaded successfully")
# Out:
# WARNING:cellwhisperer.jointemb.frozen_model:Unable to find cache file. Creating new one
# WARNING:cellwhisperer.jointemb.frozen_model:Unable to find cache file. Creating new one
# WARNING:cellwhisperer.jointemb.frozen_model:Unable to find cache file. Creating new one
# Model loaded successfully

# %%
#### Load spatial transcriptomics data ####
adata = sc.read_h5ad(snakemake.input.raw_read_count_table)
print(f"Loaded dataset with shape: {adata.shape}")
print(f"Available obs columns: {list(adata.obs.columns)}")

if metadata_col in adata.obs.columns:
    print(f"Metadata column '{metadata_col}' unique values: {adata.obs[metadata_col].value_counts()}")
else:
    print(f"Warning: Metadata column '{metadata_col}' not found in data")
    print(f"Available columns: {list(adata.obs.columns)}")
    # Use first available column as fallback
    if len(adata.obs.columns) > 0:
        metadata_col = adata.obs.columns[0]
        print(f"Using fallback column: {metadata_col}")
    else:
        raise ValueError("No metadata columns available")
# Out:
# Loaded dataset with shape: (4361, 4659)
# Available obs columns: ['in_tissue', 'x_array', 'y_array', 'x_pixel', 'y_pixel', 'sample_ID', 'barcode', 'cell_type_annotations', 'region_type_expert_annotation', 'sample_id']
# Metadata column 'cell_type_annotations' unique values: Epithelial     2711
# Immune         1156
# Endothelial     312
# Stroma          182
# Name: cell_type_annotations, dtype: int64

# %%
#### Load processed embeddings
processed_data = np.load(snakemake.input.processed_dataset)
print(f"Loaded processed data with keys: {list(processed_data.keys())}")

# Add embeddings to adata
if 'transcriptome_embeds' in processed_data:
    adata.obsm['X_transcriptome_embeddings'] = processed_data['transcriptome_embeds']
    print(f"Added transcriptome embeddings with shape: {adata.obsm['X_transcriptome_embeddings'].shape}")

# Add image embeddings if available
if 'image_embeds' in processed_data:
    adata.obsm['X_image_embeddings'] = processed_data['image_embeds']
    print(f"Added image embeddings with shape: {adata.obsm['X_image_embeddings'].shape}")
    
# Add spatial coordinates if available
if 'spatial_coordinates' in processed_data:
    adata.obsm['X_spatial'] = processed_data['spatial_coordinates']
    print(f"Added spatial coordinates with shape: {adata.obsm['X_spatial'].shape}")
# Out:
# Loaded processed data with keys: ['transcriptome_features', 'transcriptome_embeds', 'orig_ids', 'image_features', 'image_embeds', 'spatial_coordinates']
# Added transcriptome embeddings with shape: (4361, 2048)
# Added image embeddings with shape: (4361, 2048)
# Added spatial coordinates with shape: (4361, 2)

# %%
#### Prepare text queries for prediction ####
# Get unique classes from the metadata column
unique_classes = adata.obs[metadata_col].unique()
unique_classes = [c for c in unique_classes if pd.notna(c) and c not in snakemake.params["filter_classes"]] # ["UNASSIGNED"]] # 
print(f"Found {len(unique_classes)} unique classes: {unique_classes}")

# Create text descriptions for each class
if metadata_col == 'cell_type_annotations':
    text_list = [f"Sample of a {class_name} cell" for class_name in unique_classes]
elif metadata_col == 'region_type_expert_annotation':
    # Map abbreviations to full names for better text representation
    region_mapping = {
        'NOR': 'normal tissue region',
        'TUM': 'tumor tissue region', 
        'TLS': 'tertiary lymphoid structure region',
        'INFL': 'inflammatory tissue region'
    }
    text_list = [f"Sample from a {region_mapping.get(class_name, class_name)}" for class_name in unique_classes]
else:
    text_list = [f"Sample with {metadata_col} of {class_name}" for class_name in unique_classes]

print(f"Text queries: {text_list}")
# Out:
# Found 4 unique classes: ['Epithelial', 'Immune', 'Endothelial', 'Stroma']
# Text queries: ['Sample of a Epithelial cell', 'Sample of a Immune cell', 'Sample of a Endothelial cell', 'Sample of a Stroma cell']

# %%
#### Make predictions ####
# Filter data to only include cells with valid annotations
valid_mask = adata.obs[metadata_col].isin(unique_classes)
adata_filtered = adata[valid_mask].copy()
print(f"Filtered to {adata_filtered.shape[0]} cells with valid annotations")

# Perform zero-shot prediction
scores, true_classes = score_transcriptomes_vs_texts(
    transcriptome_input=torch.from_numpy(adata_filtered.obsm['X_image_embeddings']),
    text_list_or_text_embeds=text_list,
    model=cellwhisperer_model,
    batch_size=32,
    logit_scale=cellwhisperer_model.discriminator.temperature.exp(),
    average_mode="embeddings" if average_by_class else None,
    grouping_keys=adata.obs[metadata_col].values,  # only relevant if average_mode is not None, but needed for return value true_classes
    score_norm_method=None
)
# Out:
# Filtered to 4361 cells with valid annotations

# %%
scores
# Out:
# tensor([[ 1.0593, -0.5802,  0.3868,  ...,  0.6152, -0.0923, -0.5538],
#         [ 2.3999,  1.2359,  2.2641,  ...,  1.7775,  1.9710,  1.3176],
#         [ 4.1701,  0.2235,  1.6907,  ...,  0.4605,  2.6393,  0.8194],
#         [-0.3246, -0.5620,  0.2442,  ..., -1.7328, -0.4928, -0.7680]])

# %%
sm.mean(dim=1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 sm.mean(dim=1)
#
# NameError: name 'sm' is not defined

# %%
sm = scores.softmax(dim=0)
scores_T = sm.T / sm.mean(dim=1)
scores_T

# %%
pd.Series(scores_T.argmax(axis=1)).value_counts()
# Out:
# 1    1473
# 2    1285
# 0     922
# 3     681
# dtype: int64

# %%
# scores_T = (scores/scores.norm(dim=0)).T  # n_cells * n_text
predicted_labels = [unique_classes[x] for x in scores_T.argmax(axis=1)]

# %%
result_df = pd.DataFrame(index=true_classes if snakemake.params.average_by_class else adata.obs.index)
for term in text_list:
    if snakemake.params.average_by_class:
        result_df[f"score_for_{term}"] = scores_T[:, text_list.index(term)].tolist()
    else:
        result_df[f"score_for_{term}"] = adata.obs[metadata_col].apply(dict(zip(true_classes, scores_T[:, text_list.index(term)].numpy())).get)

if snakemake.params.average_by_class:
    result_df["predicted_labels"] = predicted_labels
    result_df["label"] = result_df.index
else:
    result_df["predicted_labels"] = adata.obs[metadata_col].apply(dict(zip(true_classes, predicted_labels)).get)
    result_df["label"] = adata.obs[metadata_col]

result_df["is_correct"] = (result_df["predicted_labels"] == result_df["label"])

# Store the results
result_df.to_csv(snakemake.output.predictions, index=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # scores_T = (scores/scores.norm(dim=0)).T  # n_cells * n_text
# ----> 2 predicted_labels = [unique_classes[x] for x in scores_T.argmax(axis=1)]
#       4 # %%
#       5 result_df = pd.DataFrame(index=true_classes if snakemake.params.average_by_class else adata.obs.index)
#
# NameError: name 'scores_T' is not defined

# %%
# Print summary
accuracy = (result_df['label'] == result_df['predicted_labels']).mean()
print(f"Final accuracy: {accuracy:.3f}")

# Print confusion matrix summary
confusion_summary = pd.crosstab(result_df['label'], result_df['predicted_labels'])
print("\nConfusion matrix:")
print(confusion_summary)
# Out:
# Final accuracy: 0.265
#
# Confusion matrix:
# predicted_labels  Immune
# label
# Endothelial          312
# Epithelial          2711
# Immune              1156
# Stroma               182

# %%
scores/scores.norm(dim=0)
# Out:
# tensor([[ 0.1693, -0.4795,  0.0875,  ...,  0.0526, -0.1815, -0.1399],
#         [ 0.7047,  0.8077,  0.6113,  ...,  0.8584,  0.6074,  0.7022],
#         [ 0.1776, -0.0214,  0.7701,  ...,  0.1205, -0.1863, -0.3029],
#         [-0.6658, -0.3425,  0.1602,  ..., -0.4959, -0.7506, -0.6290]])

# %%
1156/0.265
# Out:
# 4362.264150943396

# %%
# Add scores for each class to adata.obs
for i, class_name in enumerate(unique_classes):
    adata.obs[f'score_{class_name}'] = scores[i].numpy()

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 4361 × 4659
#     obs: 'in_tissue', 'x_array', 'y_array', 'x_pixel', 'y_pixel', 'sample_ID', 'barcode', 'cell_type_annotations', 'region_type_expert_annotation', 'sample_id'
#     var: 'gene_name'
#     uns: '20x_slide', 'default_embedding', 'he_slide', 'meta', 'spatial'
#     obsm: 'X_spatial', 'spatial', 'X_transcriptome_embeddings', 'X_image_embeddings'
#     layers: 'counts', 'log10k_norm_raw_counts', 'raw_counts'

# %%
adata.obsm["spatial"][:
# Out:
#   Cell In[37], line 1
#     adata.obsm["spatial"][:
#                            ^
# SyntaxError: incomplete input

# %%
adata.obsm["X_spatial"]
# Out:
# array([[ 512.21275 ,  188.475585],
#        [1858.91015 , 1561.76275 ],
#        [ 936.40095 ,  272.2447  ],
#        ...,
#        [ 725.774425, 1830.81715 ],
#        [ 680.245425, 1420.26305 ],
#        [1061.74635 ,  382.178   ]])

# %%
sc.pl.embedding(adata, color=f'LTB', cmap='viridis', use_raw=False, show=False, basis="spatial", dimensions=[(1,0)])
plt.show()

# %%
adata.var
# Out:
#          gene_name
# RASL12      RASL12
# HES2          HES2
# HERC6        HERC6
# ADAMTSL3  ADAMTSL3
# EARS2        EARS2
# ...            ...
# EMC8          EMC8
# ITPKC        ITPKC
# KCNN4        KCNN4
# EGFL6        EGFL6
# PSMA5        PSMA5
#
# [4659 rows x 1 columns]

# %%
# Plot UMAP colored by each class score
import matplotlib.pyplot as plt
for class_name in unique_classes:
    sc.pl.embedding(adata, color=f'score_{class_name}', cmap='viridis', title=f"Score: {class_name}", use_raw=False, show=False, basis="spatial", dimensions=[(1,0)])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 4
#       2 import matplotlib.pyplot as plt
#       3 for class_name in unique_classes:
# ----> 4     sc.pl.embedding(adata, color=f'score_{class_name}', cmap='viridis', title=f"Score: {class_name}", use_raw=False, show=False, basis="spatial", dimensions=[(1,0)])
#       5     plt.show()
#
# ...

# %%
adata_filtered
# Out:
# AnnData object with n_obs × n_vars = 4361 × 4659
#     obs: 'in_tissue', 'x_array', 'y_array', 'x_pixel', 'y_pixel', 'sample_ID', 'barcode', 'cell_type_annotations', 'region_type_expert_annotation', 'sample_id'
#     var: 'gene_name'
#     uns: '20x_slide', 'default_embedding', 'he_slide', 'meta', 'spatial'
#     obsm: 'X_spatial', 'spatial', 'X_transcriptome_embeddings', 'X_image_embeddings'
#     layers: 'counts', 'log10k_norm_raw_counts', 'raw_counts'

# %%
# Perform zero-shot prediction
scores, true_classes = score_transcriptomes_vs_texts(
    transcriptome_input=torch.from_numpy(adata_filtered.obsm['X_image_embeddings']),
    text_list_or_text_embeds=["T cells"],
    model=cellwhisperer_model,
    batch_size=32,
    logit_scale=cellwhisperer_model.discriminator.temperature.exp(),
    average_mode="embeddings" if average_by_class else None,
    grouping_keys=adata.obs[metadata_col].values,  # only relevant if average_mode is not None, but needed for return value true_classes
    score_norm_method=None
)
adata.obs["tmp_score"] = scores[0]
sc.pl.embedding(adata, color="tmp_score", cmap='viridis', title="T cells (LC1)", use_raw=False, show=False, basis="spatial", dimensions=[(1,0)])
# Out:
# <Axes: title={'center': 'T cells (LC1)'}, xlabel='spatial2', ylabel='spatial1'>

# %%
LTB_upreg = adata_filtered[:, ["LTB"]].X > 0.5
adata_filtered[LTB_upreg[:, 0]]
# Out:
# View of AnnData object with n_obs × n_vars = 246 × 4659
#     obs: 'in_tissue', 'x_array', 'y_array', 'x_pixel', 'y_pixel', 'sample_ID', 'barcode', 'cell_type_annotations', 'region_type_expert_annotation', 'sample_id'
#     var: 'gene_name'
#     uns: '20x_slide', 'default_embedding', 'he_slide', 'meta', 'spatial'
#     obsm: 'X_spatial', 'spatial', 'X_transcriptome_embeddings', 'X_image_embeddings'
#     layers: 'counts', 'log10k_norm_raw_counts', 'raw_counts'

# %%
# Perform zero-shot prediction
scores, true_classes = score_transcriptomes_vs_texts(
    transcriptome_input=torch.from_numpy(adata_filtered.obsm['X_image_embeddings']),
    text_list_or_text_embeds=torch.from_numpy(adata_filtered.obsm['X_transcriptome_embeddings'])[LTB_upreg[:, 0]].mean(dim=0).unsqueeze(0),
    model=cellwhisperer_model,
    batch_size=32,
    logit_scale=cellwhisperer_model.discriminator.temperature.exp(),
    average_mode="embeddings" if average_by_class else None,
    grouping_keys=adata.obs[metadata_col].values,  # only relevant if average_mode is not None, but needed for return value true_classes
    score_norm_method=None
)
adata.obs["tmp_score"] = scores[0]
sc.pl.embedding(adata, color="tmp_score", cmap='viridis', title="tmp_score", use_raw=False, show=False, basis="spatial", dimensions=[(1,0)])
plt.show()

# %%
scores[:, LTB_upreg[:, 0]].std()
# Out:
# tensor(1.0051)

# %%
torch.from_numpy(adata_filtered.obsm['X_transcriptome_embeddings'])[LTB_upreg[:, 0]].mean(dim=0).unsqueeze(0)
# Out:
# tensor([[-0.0221,  0.0138, -0.0254,  ...,  0.0043, -0.0239,  0.0090]])

# %% [markdown]
# ## Analyze patches here

# %%
# adata.uns["20x_slide"] = adata.uns["20x_slide"].transpose(1, 0, 2)  #

# %%
adata_filtered = adata

# %%
patches = cellwhisperer_image_processor(adata)
# Out:
# 4361it [00:26, 167.30it/s]

# %%
import matplotlib.pyplot as plt

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

for i in range(3):
    # Convert from CHW to HWC format for display
    patch = patches["patches"][680][i].transpose(1, 2, 0)
    axes[i].imshow(patch, origin="lower")
    axes[i].axis('off')
    axes[i].set_title(f'Patch {i+1}')

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7380952..2.622571].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7380952..2.622571].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7380952..2.535425].

# %%
adata_filtered.obsm["spatial"][680]
# Out:
# array([276.042675, 269.606475])

# %%
adata_filtered.obs["y_pixel"].max()
# Out:
# 9029.345

# %%
adata_filtered.obs["x_pixel"].iloc[680]
# Out:
# 1078.4259

# %%
adata_filtered.uns["20x_slide"][500:1500, 500:1500]
# Out:
# array([[[237, 235, 238],
#         [238, 236, 239],
#         [237, 235, 238],
#         ...,
#         [235, 231, 236],
#         [234, 230, 235],
#         [234, 230, 235]],
#
#        [[235, 233, 236],
#         [237, 235, 238],
#         [236, 234, 237],
#         ...,
#         [234, 229, 235],
#         [232, 227, 233],
#         [233, 228, 234]],
#
#        [[236, 234, 237],
#         [236, 234, 237],
#         [236, 234, 237],
#         ...,
#         [222, 217, 223],
#         [221, 216, 222],
#         [219, 214, 220]],
#
#        ...,
#
#        [[180, 165, 183],
#         [189, 176, 193],
#         [191, 179, 196],
#         ...,
#         [ 95,  63, 116],
#         [ 86,  57, 109],
#         [ 81,  53, 104]],
#
#        [[187, 172, 191],
#         [190, 177, 195],
#         [194, 183, 200],
#         ...,
#         [104,  66, 119],
#         [ 82,  48, 102],
#         [ 83,  49, 103]],
#
#        [[181, 166, 185],
#         [187, 173, 192],
#         [195, 184, 201],
# ...

# %%
adata_filtered.obsm["spatial"].sum(axis=1).argmax()
# Out:
# 3322

# %%
fig, axes = plt.subplots(1, 3, figsize=(12, 4))

for i in range(3):
    # Convert from CHW to HWC format for display
    patch = patches["patches"][3322][i].transpose(1, 2, 0)
    axes[i].imshow(patch)
    axes[i].axis('off')
    axes[i].set_title(f'Patch {i+1}')

plt.tight_layout()
plt.show()
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5455182..2.5179958].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.5455182..2.64].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7556022..2.64].

# %%
adata
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 adata
#
# NameError: name 'adata' is not defined

# %%
adata.obsm["spatial"][:, 0] / adata.obs["y_pixel"]
# Out:
# AAACAACGAATAGTTC-1    0.25
# AAACAAGTATCTCCCA-1    0.25
# AAACAATCTACTAGCA-1    0.25
# AAACACCAATAACTGC-1    0.25
# AAACAGAGCGACTCCT-1    0.25
#                       ...
# TTGTTGTGTGTCAAGA-1    0.25
# TTGTTTCACATCCAGG-1    0.25
# TTGTTTCATTAGTCTA-1    0.25
# TTGTTTCCATACAACT-1    0.25
# TTGTTTGTGTAAATTC-1    0.25
# Name: y_pixel, Length: 4361, dtype: float64

# %%
import matplotlib.pyplot as plt
plt.imshow(adata.uns["20x_slide"][00:5000, 0:5000], origin="lower")
plt.scatter(adata.obs["y_pixel"], adata.obs["x_pixel"], s=5, color="red")

plt.xlim([0, 5000])
plt.ylim([0, 5000])
# Out:
# (0.0, 5000.0)

# %%
tile = adata.uns["20x_slide"][1000:1200, 1000:1200]

from PIL import Image

xx = cellwhisperer_image_processor.transform(Image.fromarray(tile))
plt.imshow(xx.numpy().transpose(1, 2, 0), 
           origin="lower")
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.7556022..2.622571].

# %%
xx
# Out:
# tensor([[[1.9407, 1.9235, 1.9235,  ..., 1.7865, 1.8893, 1.6667],
#          [1.9407, 1.9235, 1.9407,  ..., 1.7352, 1.8379, 1.5297],
#          [1.9235, 1.9235, 1.9407,  ..., 1.7352, 1.7009, 1.6838],
#          ...,
#          [1.8550, 1.8037, 1.8037,  ..., 1.3413, 1.4269, 1.6324],
#          [1.8550, 1.8037, 1.8208,  ..., 1.4440, 1.5297, 1.6838],
#          [1.8893, 1.8379, 1.8379,  ..., 1.6838, 1.7352, 1.6495]],
#
#         [[2.0084, 1.9909, 1.9909,  ..., 1.5707, 1.6758, 1.4832],
#          [2.0084, 1.9909, 2.0084,  ..., 1.5532, 1.6583, 1.3606],
#          [1.9909, 1.9909, 2.0084,  ..., 1.5707, 1.5532, 1.5532],
#          ...,
#          [1.8508, 1.8333, 1.8333,  ..., 0.8704, 0.9930, 1.2381],
#          [1.8508, 1.8508, 1.8508,  ..., 0.9930, 1.1331, 1.3081],
#          [1.8859, 1.8683, 1.8508,  ..., 1.2381, 1.2906, 1.2206]],
#
#         [[2.2914, 2.2740, 2.2740,  ..., 2.0474, 2.1694, 1.9777],
#          [2.2914, 2.2740, 2.2914,  ..., 1.9951, 2.1346, 1.8383],
# ...

# %%
snakemake.input.raw_read_count_table
# Out:
# '/home/groups/zinaida/moritzs/cellwhisperer_private/resources/lung_tissue/read_count_table.h5ad'
