# %%
######## snakemake preamble start (automatically inserted, do not edit) ########
import sys; sys.path.extend(['/msc/home/mschae83/miniconda3/lib/python3.9/site-packages', '/msc/home/mschae83/.cache/snakemake/snakemake/source-cache/runtime-cache/tmp_tilaz_s/file/msc/home/mschae83/cellwhisperer_private/src/figures/rules/../notebooks', '/msc/home/mschae83/cellwhisperer_private/src/figures/rules/../notebooks']); import pickle; snakemake = pickle.loads(b'\x80\x04\x95V&\x00\x00\x00\x00\x00\x00\x8c\x10snakemake.script\x94\x8c\tSnakemake\x94\x93\x94)\x81\x94}\x94(\x8c\x05input\x94\x8c\x0csnakemake.io\x94\x8c\nInputFiles\x94\x93\x94)\x81\x94(\x8c\xa0/msc/home/mschae83/cellwhisperer_private/results/plots/llava/main/Mistral-7B-Instruct-v0.2__cellwhisperer_clip_v1/with50topgenesnoembedding/all_perplexities.csv\x94\x8c\x98/msc/home/mschae83/cellwhisperer_private/results/plots/llava/main/Mistral-7B-Instruct-v0.2__cellwhisperer_clip_v1/without50topgenes/all_perplexities.csv\x94\x8c\x95/msc/home/mschae83/cellwhisperer_private/results/plots/llava/main/Mistral-7B-Instruct-v0.2__cellwhisperer_clip_v1/with50topgenes/all_perplexities.csv\x94\x8cY/msc/home/mschae83/cellwhisperer_private/results/llava/evaluation/main_conversations.json\x94\x8cB/msc/home/mschae83/cellwhisperer_private/src/plot_style/main.style\x94e}\x94(\x8c\x06_names\x94}\x94(\x8c\x0cperplexities\x94K\x00K\x03\x86\x94\x8c\x12evaluation_dataset\x94K\x03N\x86\x94\x8c\tmpl_style\x94K\x04N\x86\x94u\x8c\x12_allowed_overrides\x94]\x94(\x8c\x05index\x94\x8c\x04sort\x94eh\x1a\x8c\tfunctools\x94\x8c\x07partial\x94\x93\x94h\x06\x8c\x19Namedlist._used_attribute\x94\x93\x94\x85\x94R\x94(h )}\x94\x8c\x05_name\x94h\x1asNt\x94bh\x1bh\x1eh \x85\x94R\x94(h )}\x94h$h\x1bsNt\x94bh\x12h\x06\x8c\tNamedlist\x94\x93\x94)\x81\x94(h\nh\x0bh\x0ce}\x94(h\x10}\x94h\x18]\x94(h\x1ah\x1beh\x1ah\x1eh \x85\x94R\x94(h )}\x94h$h\x1asNt\x94bh\x1bh\x1eh \x85\x94R\x94(h )}\x94h$h\x1bsNt\x94bubh\x14h\rh\x16h\x0eub\x8c\x06output\x94h\x06\x8c\x0bOutputFiles\x94\x93\x94)\x81\x94(\x8c\x89/msc/home/mschae83/cellwhisperer_private/results/plots/llava/main/ppl_model_comparison/cw_preprompt_useless/log2_ppl_ratio_individual.svg\x94\x8c\x87/msc/home/mschae83/cellwhisperer_private/results/plots/llava/main/ppl_model_comparison/cw_preprompt_useless/log2_ppl_ratio_relative.svg\x94e}\x94(h\x10}\x94(\x8c\x17individual_performances\x94K\x00N\x86\x94\x8c\x15relative_performances\x94K\x01N\x86\x94uh\x18]\x94(h\x1ah\x1beh\x1ah\x1eh \x85\x94R\x94(h )}\x94h$h\x1asNt\x94bh\x1bh\x1eh \x85\x94R\x94(h )}\x94h$h\x1bsNt\x94bh@h<hBh=ub\x8c\x06params\x94h\x06\x8c\x06Params\x94\x93\x94)\x81\x94(]\x94(}\x94(\x8c\nbase_model\x94\x8c\x18Mistral-7B-Instruct-v0.2\x94\x8c\x05model\x94\x8c\x15cellwhisperer_clip_v1\x94\x8c\x10prompt_variation\x94\x8c\x19with50topgenesnoembedding\x94u}\x94(hShThUhVhW\x8c\x11without50topgenes\x94u}\x94(hShThUhVhW\x8c\x0ewith50topgenes\x94ue]\x94(\x8c\nmacrophage\x94\x8c\x0berythrocyte\x94\x8c\x08monocyte\x94\x8c\x12type ii pneumocyte\x94\x8c\x12classical monocyte\x94\x8c\nneutrophil\x94\x8c\x1fcd4-positive, alpha-beta t cell\x94\x8c\x07nk cell\x94\x8c\x0cnaive b cell\x94\x8c\nbasal cell\x94\x8c\x1fcd8-positive, alpha-beta t cell\x94\x8c\nhepatocyte\x94\x8c;cd8-positive, alpha-beta cytokine secreting effector t cell\x94\x8c\tclub cell\x94\x8c\x16non-classical monocyte\x94\x8c\x1acapillary endothelial cell\x94\x8c&cd4-positive, alpha-beta memory t cell\x94\x8c\rmemory b cell\x94\x8c\x17respiratory goblet cell\x94\x8c\x08basophil\x94e\x8c\x0fThis cell is a \x94\x8c\x06violin\x94e}\x94(h\x10}\x94(\x8c\x13comparison_sequence\x94K\x00N\x86\x94\x8c\x0eplot_celltypes\x94K\x01N\x86\x94\x8c\x0fresponse_prefix\x94K\x02N\x86\x94\x8c\tplot_type\x94K\x03N\x86\x94uh\x18]\x94(h\x1ah\x1beh\x1ah\x1eh \x85\x94R\x94(h )}\x94h$h\x1asNt\x94bh\x1bh\x1eh \x85\x94R\x94(h )}\x94h$h\x1bsNt\x94bhvhQhxh]hzhrh|hsub\x8c\twildcards\x94h\x06\x8c\tWildcards\x94\x93\x94)\x81\x94(\x8c\x04main\x94\x8c\x14cw_preprompt_useless\x94\x8c\x0elog2_ppl_ratio\x94e}\x94(h\x10}\x94(\x8c\x07dataset\x94K\x00N\x86\x94\x8c\tplot_type\x94K\x01N\x86\x94\x8c\x0bplot_metric\x94K\x02N\x86\x94uh\x18]\x94(h\x1ah\x1beh\x1ah\x1eh \x85\x94R\x94(h )}\x94h$h\x1asNt\x94bh\x1bh\x1eh \x85\x94R\x94(h )}\x94h$h\x1bsNt\x94b\x8c\x07dataset\x94h\x8bh|h\x8ch\x94h\x8dub\x8c\x07threads\x94K\x01\x8c\tresources\x94h\x06\x8c\tResources\x94\x93\x94)\x81\x94(K\x01K\x01\x8c\x04/tmp\x94MP\xc3MD\xbae}\x94(h\x10}\x94(\x8c\x06_cores\x94K\x00N\x86\x94\x8c\x06_nodes\x94K\x01N\x86\x94\x8c\x06tmpdir\x94K\x02N\x86\x94\x8c\x06mem_mb\x94K\x03N\x86\x94\x8c\x07mem_mib\x94K\x04N\x86\x94uh\x18]\x94(h\x1ah\x1beh\x1ah\x1eh \x85\x94R\x94(h )}\x94h$h\x1asNt\x94bh\x1bh\x1eh \x85\x94R\x94(h )}\x94h$h\x1bsNt\x94bh\xa8K\x01h\xaaK\x01h\xach\xa5h\xaeMP\xc3h\xb0MD\xbaub\x8c\x03log\x94h\x06\x8c\x03Log\x94\x93\x94)\x81\x94}\x94(h\x10}\x94h\x18]\x94(h\x1ah\x1beh\x1ah\x1eh \x85\x94R\x94(h )}\x94h$h\x1asNt\x94bh\x1bh\x1eh \x85\x94R\x94(h )}\x94h$h\x1bsNt\x94bub\x8c\x06config\x94}\x94(\x8c\x12anndata_label_name\x94\x8c\x1bnatural_language_annotation\x94\x8c\x0enum_replicates\x94K\x05\x8c\x14llava_projector_type\x94\x8c\rmlp2x_8t_gelu\x94\x8c\x15precomputing_base_url\x94\x8c8https://medical-epigenomics.org/papers/schaefer2024/data\x94\x8c\x0ccluster_name\x94\x8c\x06muwhpc\x94\x8c\x05paths\x94}\x94(\x8c\x10read_count_table\x94\x8c)resources/{dataset}/read_count_table.h5ad\x94\x8c\x0fraw_annotations\x94\x8c#resources/{dataset}/annotations.tsv\x94\x8c\x16structured_annotations\x94\x8c"results/{dataset}/annotations.json\x94\x8c\x15processed_annotations\x94\x8c,results/{dataset}/processed_annotations.json\x94\x8c\x1bprocessed_multi_annotations\x94\x8c2results/{dataset}/processed_multi_annotations.json\x94\x8c\x0bgeneset_gmt\x94\x8c\x1eresults/genesets/{library}.gmt\x94\x8c\x17model_processed_dataset\x94\x8c)results/{dataset}/{model}/full_output.npz\x94\x8c\x0cfull_dataset\x94\x8c results/{dataset}/full_data.h5ad\x94\x8c\x12enrichr_terms_json\x94\x8c"resources/enrichr_terms/terms.json\x94\x8c\x17ensembl_gene_symbol_map\x94\x8c%resources/ensembl_gene_symbol_map.csv\x94\x8c\x0fjointemb_models\x94\x8c\x17results/models/jointemb\x94\x8c\nwandb_logs\x94\x8c\x15results/wandb_logging\x94\x8c\x18datamodule_prepared_path\x94\x8c/results/{dataset}/lightning-processed/{hash}.pt\x94\x8c\x05cache\x94\x8c\rresults/cache\x94\x8c\x18cancer_gene_essentiality\x94}\x94(\x8c\x0fccle_expression\x94\x8c(CCLE_RNAseq_genes_counts_20180929.gct.gz\x94\x8c\x0fessential_genes\x94\x8cEresources/cancer_gene_essentiality/CRISPRInferredCommonEssentials.csv\x94\x8c\x12nonessential_genes\x94\x8cCresources/cancer_gene_essentiality/AchillesNonessentialControls.csv\x94u\x8c\x04gsva\x94}\x94(\x8c\x06result\x94\x8c\x1eresults/{dataset}/gsva.parquet\x94\x8c\x0bcorrelation\x94\x8c/results/{dataset}/{model}/gsva_correlations.csv\x94\x8c\x1ccw_transcriptome_term_scores\x94\x8c>results/{dataset}/{model}/cw_transcriptome_term_scores.parquet\x94\x8c\x05plots\x94\x8c0results/plots/gsva_correlation/{dataset}/{model}\x94u\x8c\x05llava\x94}\x94(\x8c\x04root\x94\x8c\x0eresults/llava/\x94\x8c\x15pretrain_text_dataset\x94\x8c!results/llava/pretrain_texts.json\x94\x8c\x15finetune_text_dataset\x94\x8c)results/llava/finetune_conversations.json\x94\x8c\x17evaluation_text_dataset\x94\x8c5results/llava/evaluation/{dataset}_conversations.json\x94\x8c\x17combined_processed_data\x94\x8c1results/llava/combined_processed_data/{model}.npz\x94\x8c\x14pretrained_model_dir\x94\x8c/results/llava/pretrained/{base_model}__{model}/\x94\x8c\x13finetuned_model_dir\x94\x8c.results/llava/finetuned/{base_model}__{model}/\x94\x8c\x12evaluation_results\x94\x8cGresults/plots/llava/{dataset}/{base_model}__{model}/{prompt_variation}/\x94u\x8c\x08geo_umap\x94\x8c\x1fresults/plots/geo_umap/{model}/\x94\x8c\tablations\x94}\x94(\x8c\x06models\x94\x8c\x19results/models/ablations/\x94\x8c\x05plots\x94\x8c\x18results/plots/ablations/\x94uu\x8c\nplot_style\x94\x8c\x19src/plot_style/main.style\x94\x8c\x08datasets\x94]\x94(\x8c\x06immgen\x94\x8c\rhuman_disease\x94\x8c\x0etabula_sapiens\x94\x8c!tabula_sapiens_100_cells_per_type\x94\x8c\narchs4_geo\x94\x8c\x11development4s_raw\x94\x8c\x16development_merged5000\x94\x8c\x05car_t\x94\x8c\rbowel_disease\x94\x8c\x0egut_cell_atlas\x94\x8c\x08pancreas\x94\x8c\x1chcaorganoids_normal__primary\x94\x8c\x1dhcaorganoids_normal__organoid\x94\x8c\x1chcaorganoids_cancer__primary\x94\x8c\x1dhcaorganoids_cancer__organoid\x94e\x8c\x1dzero_shot_validation_datasets\x94]\x94(\x8c\x06immgen\x94\x8c\rhuman_disease\x94\x8c\x0etabula_sapiens\x94\x8c\x08pancreas\x94\x8c%tabula_sapiens_well_studied_celltypes\x94e\x8c.metadata_cols_per_zero_shot_validation_dataset\x94}\x94(\x8c\x06immgen\x94]\x94\x8c\x08celltype\x94a\x8c\rhuman_disease\x94]\x94(\x8c\x0fDisease_subtype\x94\x8c\x06Tissue\x94e\x8c\x08pancreas\x94]\x94\x8c\x08celltype\x94a\x8c\x0etabula_sapiens\x94]\x94(\x8c\x08celltype\x94\x8c\x0corgan_tissue\x94e\x8c%tabula_sapiens_well_studied_celltypes\x94]\x94\x8c\x08celltype\x94a\x8c!tabula_sapiens_100_cells_per_type\x94]\x94(\x8c\x08celltype\x94\x8c\x0corgan_tissue\x94eu\x8c\nllava_eval\x94}\x94(\x8c\x11question_celltype\x94\x8c\x1dWhich cell type is this cell?\x94\x8c\x18response_prefix_celltype\x94hr\x8c\x13pre_prompt_topgenes\x94]\x94(}\x94(\x8c\x04from\x94\x8c\x05human\x94\x8c\x05value\x94\x8ccRespond to my request regarding a sample of cells characterized by its top-expressed genes being {}\x94u}\x94(\x8c\x04from\x94\x8c\x03gpt\x94\x8c\x05value\x94\x8c\x1aSure. What\'s your request?\x94ue\x8c\x11question_topgenes\x94\x8cGWhich are the 50 most strongly expressed genes in this sample of cells?\x94\x8c\x18response_prefix_topgenes\x94\x8c+The 50 most strongly expressed genes are {}\x94u\x8c\x19retrieval_validation_sets\x94]\x94(\x8c\x13immgen_deduplicated\x94\x8cEhuman_disease_strictly_deduplicated_dmis-lab_biobert-v1.1_CLS_pooling\x94e\x8c\x13model_name_path_map\x94}\x94(\x8c\rcellwhisperer\x94\x8c\x15cellwhisperer_clip_v1\x94\x8c\x18cellwhisperer_geneformer\x94\x8c\x15cellwhisperer_clip_v1\x94\x8c\x11cellwhisperer_uce\x94\x8c\x19cellwhisperer_clip_v2_uce\x94\x8c\x13cellwhisperer_scgpt\x94\x8c\x1bcellwhisperer_clip_v2_scgpt\x94\x8c\ngeneformer\x94\x8c\x1cresources/geneformer-12L-30M\x94\x8c\x05scgpt\x94\x8c\x15resources/scGPT_human\x94\x8c\x03uce\x94\x8c!resources/UCE/33layer_model.torch\x94\x8c\tuce4layer\x94\x8c resources/UCE/4layer_model.torch\x94\x8c\x06biogpt\x94\x8c\x10microsoft/biogpt\x94\x8c\x04bert\x94\x8c\x15dmis-lab/biobert-v1.1\x94\x8c\x0ellava_base_llm\x94hT\x8c\x07mixtral\x94\x8c0resources/mixtral-8x7b-instruct-v0.1.Q5_K_M.gguf\x94\x8c\x07mistral\x94\x8c"resources/Mistral-7B-Instruct-v0.2\x94\x8c\x0bllama31orig\x94\x8c$resources/Llama-3.1-8B-Instruct_orig\x94\x8c\x07llama31\x94\x8c\x1fresources/Llama-3.1-8B-Instruct\x94\x8c\x07llama33\x94\x8c resources/Llama-3.3-70B-Instruct\x94u\x8c\tuce_paths\x94}\x94(\x8c\x16protein_embeddings_dir\x94\x8c resources/UCE/protein_embeddings\x94\x8c\x0foffset_pkl_path\x94\x8c!resources/UCE/species_offsets.pkl\x94\x8c\x13spec_chrom_csv_path\x94\x8c\x1fresources/UCE/species_chrom.csv\x94\x8c\x06tokens\x94\x8c\x1eresources/UCE/all_tokens.torch\x94\x8c\x0ftmp_pe_idx_path\x94\x8c\x1fresults/UCE/{name}_pe_idx.torch\x94\x8c\x0ftmp_chroms_path\x94\x8c\x1dresults/UCE/{name}_chroms.pkl\x94\x8c\x0ftmp_starts_path\x94\x8c\x1dresults/UCE/{name}_starts.pkl\x94\x8c\x10tmp_feature_path\x94\x8c\x0bresults/UCE\x94u\x8c\x05scfms\x94]\x94(\x8c\ngeneformer\x94\x8c\x05scgpt\x94\x8c\x03uce\x94e\x8c\x08genesets\x94]\x94(\x8c\x0cAzimuth_2023\x94\x8c\x1aGO_Biological_Process_2023\x94\x8c\x1aGO_Molecular_Function_2023\x94\x8c\rOMIM_Expanded\x94\x8c\x18PanglaoDB_Augmented_2021\x94\x8c\x0eTabula_Sapiens\x94e\x8c top20_lung_liver_blood_celltypes\x94]\x94(h^h_h`hahbhchdhehfhghhhihjhkhlhmhnhohphqe\x8c\x0ecelltype_terms\x94}\x94(\x8c\x0berythrocyte\x94\x8c\x0berythrocyte\x94\x8c\x07nk cell\x94\x8c\x14Natural killer cells\x94\x8c\x06t cell\x94\x8c\x07T cells\x94\x8c\x06b cell\x94\x8c\x07B cells\x94\x8c\x08platelet\x94\x8c\x0fblood platelets\x94u\x8c\x08llm_apis\x94}\x94(\x8c\x04gpt4\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x0eOPENAI_API_KEY\x94\x8c\x08base_url\x94\x8c\x1ahttps://api.openai.com/v1/\x94\x8c\nmodel_name\x94\x8c\x11gpt-4o-2024-11-20\x94u\x8c\x0cclaudesonnet\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x11ANTHROPIC_API_KEY\x94\x8c\x08base_url\x94N\x8c\nmodel_name\x94\x8c\x1aclaude-3-5-sonnet-20241022\x94u\x8c\x07llama33\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x0eOLLAMA_API_KEY\x94\x8c\x08base_url\x94\x8c+http://s0-n02.hpc.meduniwien.ac.at:8080/v1/\x94\x8c\nmodel_name\x94\x8c\x0cllama3.3:70b\x94u\x8c\x07llama31\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x0eOLLAMA_API_KEY\x94\x8c\x08base_url\x94\x8c+http://s0-n02.hpc.meduniwien.ac.at:8080/v1/\x94\x8c\nmodel_name\x94\x8c\x0bllama3.1:8b\x94u\x8c\tmistral7b\x94}\x94(\x8c\x0bapi_key_env\x94\x8c\x0eOLLAMA_API_KEY\x94\x8c\x08base_url\x94\x8c+http://s0-n02.hpc.meduniwien.ac.at:8080/v1/\x94\x8c\nmodel_name\x94\x8c\x1dmistral:7b-instruct-v0.2-fp16\x94uu\x8c\tllm_judge\x94}\x94(\x8c\x10request_template\x94\x8cM Sample annotation: {annotation}\nTop expressed normalized genes: {top_genes} \x94\x8c\x12instruction_prompt\x94X\n\x01\x00\x00Help me analyzing this sample of cells. Respond in proper english in a tone of uncertainty and focus on the biology of the sample rather than any potential donor or patient information (e.g. do not mention age and sex). Start by listing the top genes in this sample.\x94\x8c\x14instruction_response\x94\x8cuSure. The top normalized genes are {top_genes}. Note that are strongly expressed genes beyond the ones I just listed.\x94\x8c\x1cinstruction_prompt_text_only\x94X%\x01\x00\x00Respond to my request regarding a sample of cells characterized by their top-expressed genes. Respond directly and concisely without much contemplation and in less than 3 sentences with a tone of uncertainty and a focus on the biology of the sample.\nTop genes: {top_genes}\nRequest: {question} \x94uu\x8c\x04rule\x94\x8c"llava_comparative_perplexity_plots\x94\x8c\x0fbench_iteration\x94N\x8c\tscriptdir\x94\x8cG/msc/home/mschae83/cellwhisperer_private/src/figures/rules/../notebooks\x94ub.'); from snakemake.logging import logger; logger.printshellcmds = False; import os; os.chdir(r'/msc/home/mschae83/cellwhisperer_private/src/figures');
######## snakemake preamble end #########

# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib

matplotlib.style.use(snakemake.input.mpl_style)
plot_fn = sns.violinplot if snakemake.params.plot_type == "violin" else sns.boxplot

# %%
snakemake.params.comparison_sequence
# Out:
# [{'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'cellwhisperer_clip_v1',
#   'prompt_variation': 'with50topgenesnoembedding'},
#  {'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'cellwhisperer_clip_v1',
#   'prompt_variation': 'without50topgenes'},
#  {'base_model': 'Mistral-7B-Instruct-v0.2',
#   'model': 'cellwhisperer_clip_v1',
#   'prompt_variation': 'with50topgenes'}]

# %%
keys = snakemake.params.comparison_sequence[0]

common_fields = {
    key: snakemake.params.comparison_sequence[0][key]
    for key in snakemake.params.comparison_sequence[0]
    if len(set([v[key] for v in snakemake.params.comparison_sequence])) == 1
}
common_fields
# Out:
# {'base_model': 'Mistral-7B-Instruct-v0.2', 'model': 'cellwhisperer_clip_v1'}

# %%
dfs = []
config_order = []  # for plotting later
for params, fn in zip(
    snakemake.params.comparison_sequence, snakemake.input.perplexities
):
    config_str = "__".join(
        [v for k, v in params.items() if k not in common_fields.keys()]
    )
    dfs.append(pd.read_csv(fn, index_col=0))
    dfs[-1]["configuration"] = config_str
    for key, value in params.items():
        dfs[-1][key] = value

    config_order.append(config_str)

df = pd.concat(dfs)
df
# Out:
#      eval_loss  eval_model_preparation_time  eval_perplexity  \
# 0     0.850513                       0.0043         1.978047
# 1     0.850513                       0.0043         1.978047
# 2     0.850513                       0.0043         1.978047
# 3     0.850513                       0.0043         1.978047
# 4     0.850513                       0.0043         1.978047
# ..         ...                          ...              ...
# 195   1.149102                       0.0039         2.797266
# 196   1.149102                       0.0039         2.797266
# 197   1.149102                       0.0039         2.797266
# 198   1.149102                       0.0039         2.797266
# 199   1.149102                       0.0039         2.797266
#
#      eval_all_perplexities  eval_runtime  eval_samples_per_second  \
# 0                 2.546875       15.7935                   12.663
# 1                 2.078125       15.7935                   12.663
# ...

# %%
if np.isnan(df["question_id"]).any():
    df["question_id"] = df.index

# %%
import json

with open(snakemake.input.evaluation_dataset) as f:
    evaluation_dataset = json.load(f)
evaluation_dataset

df["question"] = df["question_id"].map(
    lambda i: evaluation_dataset[i]["conversations"][0]["value"]
)

df["response"] = df["question_id"].map(
    lambda i: evaluation_dataset[i]["conversations"][1]["value"].replace(
        snakemake.params.response_prefix, ""
    )
)

# %%
df.iloc[0]
# Out:
# eval_loss                                                               0.850513
# eval_model_preparation_time                                               0.0043
# eval_perplexity                                                         1.978047
# eval_all_perplexities                                                   2.546875
# eval_runtime                                                             15.7935
# eval_samples_per_second                                                   12.663
# eval_steps_per_second                                                      1.583
# response                       This sample appears to be a glial cell derived...
# type                                                                     correct
# question_id                                                                    0
# replicate                                                                     -1
# configuration                                          with50topgenesnoembedding
# ...

# %% [markdown]
# ## Strategy
#
# 1. Compute the expected (i.e. mean over the 30 mismatched cases) ppl ratio between correct and incorrect embedding
# 2. plot method-grouped violin plots of these ratios
#
# ### For main and TabSap
#
# - violinplots across all responses
#
# ### For TabSap
#
# - Make 20 plots (4x5) for the selected ones
# - For the full 177 cell types:
#   - Just take the ranks (how often was method A first, how often was B first, how often was C first, ...)

# %%
if snakemake.wildcards.plot_metric == "log2_ppl_ratio":
    # Compute the expected perplexity ratio for each model
    def ppl_ratio(group):
        correct = group.loc[group.type == "correct", "eval_all_perplexities"]
        assert len(correct) == 1, "There should be exactly one correct answer"
        incorrect = group.loc[group.type == "incorrect", "eval_all_perplexities"]

        return correct.iloc[0] / incorrect.mean()

    ppl_ratios = (
        df.groupby(
            ["configuration", "question_id"]
            + list(snakemake.params.comparison_sequence[0].keys())
        )
        .apply(ppl_ratio)
        .reset_index()
    )
    response = df.drop_duplicates(
        subset=["question_id", "configuration", "response"]
    ).set_index(["question_id", "configuration"])["response"]
    ppl_ratios["response"] = ppl_ratios.apply(
        lambda row: response.loc[row["question_id"], row["configuration"]], axis=1
    )
    ppl_ratios[snakemake.wildcards.plot_metric] = np.log2(ppl_ratios[0])

    ppl_df = ppl_ratios.reset_index()
elif snakemake.wildcards.plot_metric == "log2_correct_ppl":
    # just show the (log2) of the (correct) perplexity
    ppl_df = (
        df[df.type == "correct"]
        .groupby(
            ["configuration", "question_id", "response"]
            + list(snakemake.params.comparison_sequence[0].keys())
        )["eval_all_perplexities"]
        .mean()
        .apply(np.log2)
        .reset_index()
    )
    ppl_df[snakemake.wildcards.plot_metric] = ppl_df["eval_all_perplexities"]

# %%
ppl_df.configuration.unique()
# Out:
# array(['with50topgenes', 'with50topgenesnoembedding', 'without50topgenes'],
#       dtype=object)

# %%
# the good examples in `with50topgenesnoembedding` and `with50topgenes` are the same:
try:
    sns.scatterplot(data=ppl_df.query("configuration != 'without50topgenes'").pivot_table(columns="configuration", values=["log2_ppl_ratio"], index="question_id")["log2_ppl_ratio"],
                x="with50topgenesnoembedding",
                y="with50topgenes")
except:
    pass

# %%
ppl_df
# Out:
#      index      configuration  question_id                base_model  \
# 0        0     with50topgenes            0  Mistral-7B-Instruct-v0.2
# 1        1     with50topgenes            1  Mistral-7B-Instruct-v0.2
# 2        2     with50topgenes            2  Mistral-7B-Instruct-v0.2
# 3        3     with50topgenes            3  Mistral-7B-Instruct-v0.2
# 4        4     with50topgenes            4  Mistral-7B-Instruct-v0.2
# ..     ...                ...          ...                       ...
# 595    595  without50topgenes          195  Mistral-7B-Instruct-v0.2
# 596    596  without50topgenes          196  Mistral-7B-Instruct-v0.2
# 597    597  without50topgenes          197  Mistral-7B-Instruct-v0.2
# 598    598  without50topgenes          198  Mistral-7B-Instruct-v0.2
# 599    599  without50topgenes          199  Mistral-7B-Instruct-v0.2
#
#                      model   prompt_variation         0  \
# 0    cellwhisperer_clip_v1     with50topgenes  0.957134
# ...

# %%
try:
    pd.set_option('display.max_colwidth', None)
    ppl_df.query("configuration == 'with50topgenes'").sort_values("log2_ppl_ratio")
except:
    pass
# Out:
#      index   configuration  question_id                base_model  \
# 52      52  with50topgenes           52  Mistral-7B-Instruct-v0.2
# 195    195  with50topgenes          195  Mistral-7B-Instruct-v0.2
# 174    174  with50topgenes          174  Mistral-7B-Instruct-v0.2
# 128    128  with50topgenes          128  Mistral-7B-Instruct-v0.2
# 93      93  with50topgenes           93  Mistral-7B-Instruct-v0.2
# ..     ...             ...          ...                       ...
# 5        5  with50topgenes            5  Mistral-7B-Instruct-v0.2
# 85      85  with50topgenes           85  Mistral-7B-Instruct-v0.2
# 75      75  with50topgenes           75  Mistral-7B-Instruct-v0.2
# 167    167  with50topgenes          167  Mistral-7B-Instruct-v0.2
# 152    152  with50topgenes          152  Mistral-7B-Instruct-v0.2
#
#                      model prompt_variation         0  \
# 52   cellwhisperer_clip_v1   with50topgenes  0.191284
# 195  cellwhisperer_clip_v1   with50topgenes  0.194256
# ...

# %%
# Plot individual performance


x = "configuration"
hue = None
order = config_order
hue_order = None
width = 0.75 * ppl_df[x].nunique()

if snakemake.wildcards.plot_type == "llava_cw_vs_geneformer":
    x = "prompt_variation"
    hue = "model"
    order = np.unique([v[x] for v in snakemake.params.comparison_sequence])
if snakemake.wildcards.plot_type == "gene_predictability":
    pass
if snakemake.wildcards.plot_type == "text_only_vs_cw":
    ppl_df["mismatch_method"] = ppl_df["prompt_variation"].apply(lambda v: "response permuted" if v.endswith("responsepermuted") else "transcriptome permuted")
    ppl_df["configuration_trimmed"] = ppl_df["configuration"].apply(lambda v: v.replace("responsepermuted", ""))
    x = "mismatch_method"
    hue = "configuration_trimmed"
    
    width = 0.5 * ppl_df[x].nunique() * ppl_df[hue].nunique()
    
    order = ["transcriptome permuted", "response permuted"]
    hue_order = [c for c in config_order if not c.endswith("responsepermuted")]    
if snakemake.wildcards.plot_type == "cw_preprompt_useless":
    pass

fig, ax = plt.subplots(figsize=(width, 6))
plot_fn(
    data=ppl_df,
    x=x,
    y=snakemake.wildcards.plot_metric,
    hue=hue,
    ax=ax,
    order=order,
)
# theoretical baseline
if snakemake.wildcards.plot_metric == "log2_ppl_ratio":
    ax.axhline(0, color="gray", linestyle="--")

ax.set_title(
    f"{snakemake.wildcards.plot_type}, {snakemake.wildcards.dataset}  ({', '.join(common_fields.values())})"
)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
ax.legend(loc="lower left")

# plt.tight_layout()


fig.savefig(snakemake.output.individual_performances)
# Out:
# /tmp/ipykernel_4165147/2134354077.py:45: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, ha="right")
# /tmp/ipykernel_4165147/2134354077.py:46: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend(loc="lower left")

# %% [markdown]
# A bit disturbing that Mistral-7B__NONE with top 50 genes (blue) is better than any multimodal LLM.
# Reason though: The negatives (wrong embeddings) as (as well as the positives) in the original Mistral lead to much larger ppls.
#
# Thus better would be to normalize across the mean of all negatives?

# %% [markdown]
# ### Relative comparisons

# %%
from itertools import combinations

# Find unique configurations
configurations = ppl_df["configuration"].unique()

# Initialize comparison matrix
comparison_matrix = pd.DataFrame(0, index=configurations, columns=configurations)

# Compare configurations
for question_id, group in ppl_df.groupby("question_id"):
    pairs = combinations(group["configuration"], 2)
    for config1, config2 in pairs:
        value1 = group.loc[
            group["configuration"] == config1, snakemake.wildcards.plot_metric
        ].values[0]
        value2 = group.loc[
            group["configuration"] == config2, snakemake.wildcards.plot_metric
        ].values[0]
        if value1 <= value2:
            comparison_matrix.loc[config1, config2] += 1
            comparison_matrix.loc[config2, config1] -= 1
        if value1 >= value2:
            comparison_matrix.loc[config2, config1] += 1
            comparison_matrix.loc[config1, config2] -= 1

# Normalize the matrix to get percentages
# comparison_matrix = comparison_matrix.div(comparison_matrix.sum(axis=1), axis=0) * 100

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    comparison_matrix,
    annot=True,
    cmap="RdBu",
    center=0,
    cbar_kws={"label": "Relative performance"},
)
plt.title(f"Configuration Performance Comparison {snakemake.wildcards.plot_metric}")
plt.xlabel("Configuration")
plt.ylabel("Configuration")


if snakemake.wildcards.plot_type != "llava_cw_vs_geneformer":
    plt.savefig(snakemake.output.relative_performances)

# %%
if snakemake.wildcards.plot_type == "llava_cw_vs_geneformer":

    plot_df = comparison_matrix.copy()
    plot_df.index = pd.MultiIndex.from_tuples(
        list(map(tuple, comparison_matrix.index.str.split("__")))
    )
    plot_df.columns = pd.MultiIndex.from_tuples(
        list(map(tuple, comparison_matrix.columns.str.split("__")))
    )

    plot_df = plot_df.loc["cellwhisperer_clip_v1", "geneformer"]
    diagonal_series = pd.Series(np.diag(plot_df), index=plot_df.index)
    ax = diagonal_series.plot(kind="bar")
    ax.set(
        ylabel="Num elements where CW is better.",
        title="point-wise comparison between CW and geneformer",
    )
    ax.axhline(0, color="black")
    plt.savefig(snakemake.output.relative_performances)

# %% [markdown]
# ### By cell type (works for tab sap only)
#
#
# - Make 20 plots (4x5) for the selected ones
# - For the full 177 cell types:
#   - Just take the ranks (how often was method A first, how often was B first, how often was C first, ...)

# %%
fig, axes = plt.subplots(4, 5, figsize=(20, 16), sharex=True, sharey=True)
for ax, celltype in zip(axes.ravel(), snakemake.params.plot_celltypes):
    # Plot the ratio of positive to negative perplexities
    plot_fn(
        data=ppl_df.loc[ppl_df.response == celltype].reset_index(),
        x="configuration",
        y=snakemake.wildcards.plot_metric,
        ax=ax,
    )
    ax.set_title(celltype)

# For lowest row, set x labels
for ax in axes[-1]:
    ax.set_xticklabels(ax.get_xticklabels(), rotation=90, ha="right")

plt.tight_layout()

# plt.savefig(snakemake.output.by_celltype)
